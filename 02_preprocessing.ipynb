# %%
import pandas as pd
import numpy as np
from sklearn.preprocessing import MinMaxScaler
import os

tickers = [
    "AAPL", "MSFT", "GOOGL", "META", "AMZN", "NFLX", "TSLA", "ABNB",
    "NVDA", "AMD", "INTC", "QCOM", "AVGO", "MU", "ARM", "AMAT",
    "V", "MA", "PYPL", "COIN", "HOOD",
    "JPM", "GS", "BAC", "WFC", "MS", "BLK",
    "CRM", "NOW", "SNOW", "PLTR", "NET", "DDOG", "MDB",
    "WMT", "TGT", "COST", "EBAY", "SHOP",
    "UNH", "ISRG", "DXCM",
    "ENPH", "FSLR", "RIVN"
]
os.makedirs("data/processed", exist_ok=True)

# %%
for ticker in tickers:
    df = pd.read_csv(f"data/raw/{ticker}_price.csv", index_col=0)
    df.index = pd.to_datetime(df.index)
    missing = df.isnull().sum().sum()
    print(f"{ticker}: {len(df)} 行, 缺失值 {missing} 个")
# Out:
# AAPL: 1509 行, 缺失值 0 个
# MSFT: 1509 行, 缺失值 0 个
# GOOGL: 1509 行, 缺失值 0 个
# META: 1509 行, 缺失值 0 个
# AMZN: 1509 行, 缺失值 0 个
# NFLX: 1509 行, 缺失值 0 个
# TSLA: 1509 行, 缺失值 0 个
# ABNB: 1019 行, 缺失值 0 个
# NVDA: 1509 行, 缺失值 0 个
# AMD: 1509 行, 缺失值 0 个
# INTC: 1509 行, 缺失值 0 个
# QCOM: 1509 行, 缺失值 0 个
# AVGO: 1509 行, 缺失值 0 个
# MU: 1509 行, 缺失值 0 个
# ARM: 326 行, 缺失值 0 个
# AMAT: 1509 行, 缺失值 0 个
# V: 1509 行, 缺失值 0 个
# MA: 1509 行, 缺失值 0 个
# PYPL: 1509 行, 缺失值 0 个
# COIN: 935 行, 缺失值 0 个
# HOOD: 861 行, 缺失值 0 个
# JPM: 1509 行, 缺失值 0 个
# GS: 1509 行, 缺失值 0 个
# BAC: 1509 行, 缺失值 0 个
# WFC: 1509 行, 缺失值 0 个
# MS: 1509 行, 缺失值 0 个
# BLK: 1509 行, 缺失值 0 个
# CRM: 1509 行, 缺失值 0 个
# NOW: 1509 行, 缺失值 0 个
# SNOW: 1079 行, 缺失值 0 个
# PLTR: 1069 行, 缺失值 0 个
# NET: 1333 行, 缺失值 0 个
# DDOG: 1329 行, 缺失值 0 个
# MDB: 1509 行, 缺失值 0 个
# WMT: 1509 行, 缺失值 0 个
# TGT: 1509 行, 缺失值 0 个
# COST: 1509 行, 缺失值 0 个
# EBAY: 1509 行, 缺失值 0 个
# SHOP: 1509 行, 缺失值 0 个
# UNH: 1509 行, 缺失值 0 个
# ISRG: 1509 行, 缺失值 0 个
# DXCM: 1509 行, 缺失值 0 个
# ENPH: 1509 行, 缺失值 0 个
# FSLR: 1509 行, 缺失值 0 个
# RIVN: 788 行, 缺失值 0 个

# %%
print("=== 数据质量报告 ===")
for ticker in tickers:
    raw = pd.read_csv(f"data/raw/{ticker}_price.csv", index_col=0)
    clean = pd.read_csv(f"data/processed/{ticker}_clean.csv", index_col=0)
    print(f"{ticker}: 原始 {len(raw)} 行 → 清洗后 {len(clean)} 行")
# Out:
# AAPL 处理完成，1509 行
# MSFT 处理完成，1509 行
# GOOGL 处理完成，1509 行
# META 处理完成，1509 行
# AMZN 处理完成，1509 行
# NFLX 处理完成，1509 行
# TSLA 处理完成，1509 行
# ABNB 处理完成，1019 行
# NVDA 处理完成，1509 行
# AMD 处理完成，1509 行
# INTC 处理完成，1509 行
# QCOM 处理完成，1509 行
# AVGO 处理完成，1509 行
# MU 处理完成，1509 行
# ARM 处理完成，326 行
# AMAT 处理完成，1509 行
# V 处理完成，1509 行
# MA 处理完成，1509 行
# PYPL 处理完成，1509 行
# COIN 处理完成，935 行
# HOOD 处理完成，861 行
# JPM 处理完成，1509 行
# GS 处理完成，1509 行
# BAC 处理完成，1509 行
# WFC 处理完成，1509 行
# MS 处理完成，1509 行
# BLK 处理完成，1509 行
# CRM 处理完成，1509 行
# NOW 处理完成，1509 行
# SNOW 处理完成，1079 行
# PLTR 处理完成，1069 行
# NET 处理完成，1333 行
# DDOG 处理完成，1329 行
# MDB 处理完成，1509 行
# WMT 处理完成，1509 行
# TGT 处理完成，1509 行
# COST 处理完成，1509 行
# EBAY 处理完成，1509 行
# SHOP 处理完成，1509 行
# UNH 处理完成，1509 行
# ISRG 处理完成，1509 行
# DXCM 处理完成，1509 行
# ENPH 处理完成，1509 行
# FSLR 处理完成，1509 行
# RIVN 处理完成，788 行

# %%
print("=== 数据质量报告 ===")
for ticker in tickers:
    raw = pd.read_csv(f"data/raw/{ticker}_price.csv", header=[0,1], index_col=0)
    clean = pd.read_csv(f"data/processed/{ticker}_clean.csv", index_col=0)
    print(f"{ticker}: 原始 {len(raw)} 行 → 清洗后 {len(clean)} 行")
# Out:
# === 数据质量报告 ===
# AAPL: 原始 1509 行 → 清洗后 1509 行
# MSFT: 原始 1509 行 → 清洗后 1509 行
# GOOGL: 原始 1509 行 → 清洗后 1509 行
# META: 原始 1509 行 → 清洗后 1509 行
# AMZN: 原始 1509 行 → 清洗后 1509 行
# NFLX: 原始 1509 行 → 清洗后 1509 行
# TSLA: 原始 1509 行 → 清洗后 1509 行
# ABNB: 原始 1019 行 → 清洗后 1019 行
# NVDA: 原始 1509 行 → 清洗后 1509 行
# AMD: 原始 1509 行 → 清洗后 1509 行
# INTC: 原始 1509 行 → 清洗后 1509 行
# QCOM: 原始 1509 行 → 清洗后 1509 行
# AVGO: 原始 1509 行 → 清洗后 1509 行
# MU: 原始 1509 行 → 清洗后 1509 行
# ARM: 原始 326 行 → 清洗后 326 行
# AMAT: 原始 1509 行 → 清洗后 1509 行
# V: 原始 1509 行 → 清洗后 1509 行
# MA: 原始 1509 行 → 清洗后 1509 行
# PYPL: 原始 1509 行 → 清洗后 1509 行
# COIN: 原始 935 行 → 清洗后 935 行
# HOOD: 原始 861 行 → 清洗后 861 行
# JPM: 原始 1509 行 → 清洗后 1509 行
# GS: 原始 1509 行 → 清洗后 1509 行
# BAC: 原始 1509 行 → 清洗后 1509 行
# WFC: 原始 1509 行 → 清洗后 1509 行
# MS: 原始 1509 行 → 清洗后 1509 行
# BLK: 原始 1509 行 → 清洗后 1509 行
# CRM: 原始 1509 行 → 清洗后 1509 行
# NOW: 原始 1509 行 → 清洗后 1509 行
# SNOW: 原始 1079 行 → 清洗后 1079 行
# PLTR: 原始 1069 行 → 清洗后 1069 行
# NET: 原始 1333 行 → 清洗后 1333 行
# DDOG: 原始 1329 行 → 清洗后 1329 行
# MDB: 原始 1509 行 → 清洗后 1509 行
# WMT: 原始 1509 行 → 清洗后 1509 行
# TGT: 原始 1509 行 → 清洗后 1509 行
# COST: 原始 1509 行 → 清洗后 1509 行
# EBAY: 原始 1509 行 → 清洗后 1509 行
# SHOP: 原始 1509 行 → 清洗后 1509 行
# UNH: 原始 1509 行 → 清洗后 1509 行
# ISRG: 原始 1509 行 → 清洗后 1509 行
# DXCM: 原始 1509 行 → 清洗后 1509 行
# ENPH: 原始 1509 行 → 清洗后 1509 行
# FSLR: 原始 1509 行 → 清洗后 1509 行
# RIVN: 原始 788 行 → 清洗后 788 行
